# %% [markdown]
# <a href="https://colab.research.google.com/github/zzzeeshannn/pitree/blob/master/PiTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
CSE 534 Project : PiTree

Authors: 
Zeeshan Shaikh 
Zhilin Zou
Yiyun Yang
"""
# Out:
# '\nCSE 534 Project : PiTree\n\nAuthors: \nZeeshan Shaikh \nZhilin Zou\nYiyun Yang\n'

# %%
# !apt-get install python3.7
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python3.7 is already the newest version (3.7.12-1+bionic1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/transys-project/pitree.git
# %cd /content/pitree
# Out:
# Cloning into 'pitree'...
# remote: Enumerating objects: 154, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 154 (delta 3), reused 6 (delta 2), pack-reused 143
# Receiving objects: 100% (154/154), 16.42 MiB | 28.11 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/pitree

# %%
# !pip install -r requirements.txt
# !unzip traces.zip
# !unzip models.zip
# !mkdir results
# !mkdir decision_tree
# !mkdir precision
# !mkdir time
# Out:
# ...
#      |████████████████████████████████| 20.3 MB 73.4 MB/s
# ...
#      |████████████████████████████████| 110.5 MB 35 kB/s
# ...
#      |████████████████████████████████| 98 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 56.1 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 37.9 MB/s
# ...
#      |████████████████████████████████| 503 kB 68.8 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.7 MB/s
# ...
#   Created wheel for tflearn: filename=tflearn-0.3.2-py3-none-any.whl size=128207 sha256=697c47986e64bd2d4b8d667a27c73b919424d8a842f96a425ed5810a854cc922
#   Stored in directory: /root/.cache/pip/wheels/8e/b7/55/b387552a28a2fefa559a362ffe17c97fac7e618ef948930b3c
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=b2475b745a256875fd22722b8e55d7666ace3d11da8f5604777a811570bf8d1f
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built tflearn gast
# ...
#   Attempting uninstall: numpy
# ...

# %%
#run test
# !python learn_dt.py -a pensieve -t fcc -i 500 -n 100 -q lin
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# ...

# %%
# !python main.py -a pensieve -t fcc -q lin -d decision_tree/pensieve_fcc_100.pk3 -l
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# ...

# %%
pip install xgboost

# %%
# !git clone https://github.com/zzzeeshannn/pitree
# %cd /content/pitree
# Out:
# Cloning into 'pitree'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 187 (delta 24), reused 30 (delta 13), pack-reused 143
# Receiving objects: 100% (187/187), 16.42 MiB | 32.53 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# /content/pitree

# %%
# !pip install -r requirements.txt
# !unzip traces.zip
# !unzip models.zip
# !mkdir results
# !mkdir decision_tree
# !mkdir precision
# !mkdir time
# Out:
# ...
#      |████████████████████████████████| 20.3 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 110.5 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 98 kB 9.3 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 894 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 16.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.4 MB/s
# ...
#      |████████████████████████████████| 503 kB 63.3 MB/s
# ...
#   Created wheel for tflearn: filename=tflearn-0.3.2-py3-none-any.whl size=128207 sha256=0576a637811a291b4c6569592ecdfc00920c63e31f284873ad731e61f93d17e2
#   Stored in directory: /root/.cache/pip/wheels/8e/b7/55/b387552a28a2fefa559a362ffe17c97fac7e618ef948930b3c
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=d2744cffd7c5b05f393169e0962aa2916972e793b72d9f41e65880c277eb5364
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built tflearn gast
# ...
#   Attempting uninstall: numpy
# ...

# %%
#run train
# !python train_dt_ada.py -a pensieve -t fcc -i 200 -n 200 -q lin
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# ...

# %%
# !python main.py -a pensieve -t fcc -q lin -d decision_tree/ada_pensieve_fcc_200.pk3 -l
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/config.py:123: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/config.py:129: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# ...

# %%
# !cp -r "/content/pitree/decision_tree" "/content/drive/MyDrive/ada"
# Out:
# cp: invalid option -- 'w'
# Try 'cp --help' for more information.

# %%
# !cp -r "/content/pitree/precision" "/content/drive/MyDrive/ada"

# %%
# !cp -r "/content/pitree/time" "/content/drive/MyDrive/ada"

# %%
# !cp -r "/content/pitree/results" "/content/drive/MyDrive/ada"

# %% [markdown]
# ID3

# %%
pip install decision-tree-id3
# Out:
# ...
#      |████████████████████████████████| 154 kB 30.3 MB/s
# ...
#   Created wheel for decision-tree-id3: filename=decision_tree_id3-0.1.2-py3-none-any.whl size=15960 sha256=7ed8178e24c2abce9f94f63136c4c8d12ddb96c4d16644db6dba2b6a0821f345
#   Stored in directory: /root/.cache/pip/wheels/19/24/be/ceeb7146de9186dada6000e36b040c6724548cd7ecbf7c557e
# Successfully built decision-tree-id3
# ...

# %%
# !git clone https://github.com/svaante/decision-tree-id3.git
# %cd /content/decision-tree-id3
# !python setup.py install
# Out:
# Cloning into 'decision-tree-id3'...
# remote: Enumerating objects: 1733, done.
# remote: Total 1733 (delta 0), reused 0 (delta 0), pack-reused 1733
# Receiving objects: 100% (1733/1733), 2.05 MiB | 24.66 MiB/s, done.
# Resolving deltas: 100% (1148/1148), done.
# /content/decision-tree-id3
# /usr/local/lib/python3.7/dist-packages/setuptools/dist.py:700: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   % (opt, underscore_opt))
# running install
# running bdist_egg
# running egg_info
# creating decision_tree_id3.egg-info
# writing decision_tree_id3.egg-info/PKG-INFO
# writing dependency_links to decision_tree_id3.egg-info/dependency_links.txt
# writing requirements to decision_tree_id3.egg-info/requires.txt
# writing top-level names to decision_tree_id3.egg-info/top_level.txt
# writing manifest file 'decision_tree_id3.egg-info/SOURCES.txt'
# ...

# %%
# !git clone https://github.com/zzzeeshannn/pitree
# %cd pitree/
# Out:
# Cloning into 'pitree'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 187 (delta 24), reused 30 (delta 13), pack-reused 143
# Receiving objects: 100% (187/187), 16.42 MiB | 34.11 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# /content/decision-tree-id3/pitree

# %%
# !pip install -r requirements.txt
# !unzip traces.zip
# !unzip models.zip
# !mkdir results
# !mkdir decision_tree
# !mkdir precision
# !mkdir time
# Out:
# ...
#      |████████████████████████████████| 20.3 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 110.5 MB 38 kB/s
# ...
#      |████████████████████████████████| 98 kB 7.5 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 39.0 MB/s
# ...
#      |████████████████████████████████| 503 kB 32.6 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.8 MB/s
# ...
#   Created wheel for tflearn: filename=tflearn-0.3.2-py3-none-any.whl size=128207 sha256=0f7c66fb2cf4ca9271597207a58e7ca6828a76b954ce023864cefcf53ba2a1a3
#   Stored in directory: /root/.cache/pip/wheels/8e/b7/55/b387552a28a2fefa559a362ffe17c97fac7e618ef948930b3c
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=b0c11d17fdc146c9fa777669b0dd011758e70ae00ea9a12e779169aa3de1a6d0
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built tflearn gast
# ...
#   Attempting uninstall: numpy
# ...

# %%
#run train
# !python train_dt_id3.py -a pensieve -t fcc -i 100 -n 100 -q lin
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/summarizer.py:9: The name tf.summary.merge is deprecated. Please use tf.compat.v1.summary.merge instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/helpers/trainer.py:25: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tflearn/collections.py:13: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# ...

# %%
# !cp -r "/content/decision-tree-id3/pitree/decision_tree" "/content/drive/MyDrive/id3"

# %%
# !python main.py -a pensieve -t fcc -q lin -d decision_tree/ada_pensieve_fcc_200.pk3 -l
